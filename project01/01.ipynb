# %%
import requests
import pprint
from datetime import datetime, timedelta
from decouple import config

key = config('MOVIE_KEY')
targetDt = '20190713' # yyyymmdd
week = '0'
per = {}
total = {}
audiAcc = []
movieCd = []
movieNm = []
c = 0
for i in range(50):
    api_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}&weekGb={week}'
    print(api_url)
    response = requests.get(api_url).json()
    targetDt = datetime.strptime(targetDt, '%Y%m%d').date()
    targetDt += timedelta(days=-7)
    targetDt = targetDt.strftime('%Y%m%d')

#     for j in range(10):
#         if response['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'] not in movieCd:
#             audiAcc.append(int(response['boxOfficeResult']['weeklyBoxOfficeList'][j]['audiAcc']))
#             movieCd.append(response['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'])
#             movieNm.append(response['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieNm'])
#             per['영화제목'] = movieNm[-1]
#             per['영화코드'] = movieCd[-1]
#             per['누적순위'] = audiAcc[-1]            
#             total[(i+1)*j] = per

    for movie in response['boxOfficeResult']['weeklyBoxOfficeList']:
        if movie['movieCd'] not in total.keys():
            total[movie['movieCd']] = {
                'movieCd': movie['movieCd'],
                'movieNm': movie['movieNm'],
                'audiAcc': movie['audiAcc']
            }
            

print(total)
# Out:
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=896e0630e1c45d2f0cd6b6976b1e6391&targetDt=20190713&weekGb=0
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=896e0630e1c45d2f0cd6b6976b1e6391&targetDt=20190706&weekGb=0
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=896e0630e1c45d2f0cd6b6976b1e6391&targetDt=20190629&weekGb=0
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=896e0630e1c45d2f0cd6b6976b1e6391&targetDt=20190622&weekGb=0
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=896e0630e1c45d2f0cd6b6976b1e6391&targetDt=20190615&weekGb=0
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=896e0630e1c45d2f0cd6b6976b1e6391&targetDt=20190608&weekGb=0
# ...

# %%
pprint.pprint(response)
# Out:
# [{'boxOfficeResult': {'boxofficeType': '주간 박스오피스',
#                       'showRange': '20190708~20190714',
#                       'weeklyBoxOfficeList': [{'audiAcc': '6685160',
#                                                'audiChange': '-52.1',
#                                                'audiCnt': '2163534',
#                                                'audiInten': '-2357236',
#                                                'movieCd': '20196309',
#                                                'movieNm': '스파이더맨: 파 프롬 홈',
#                                                'openDt': '2019-07-02',
#                                                'rank': '1',
#                                                'rankInten': '0',
#                                                'rankOldAndNew': 'OLD',
#                                                'rnum': '1',
#                                                'salesAcc': '57709536740',
# ...

# %%
audiAcc = []
movieCd = []
movieNm = []
# audiAcc.append(response['boxOfficeResult']['weeklyBoxOfficeList'][0]['audiAcc'])
for i in range(3):
    for j in range(10):
        if response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'] not in movieCd:
            audiAcc.append(int(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['audiAcc']))
            movieCd.append(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'])
            movieNm.append(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieNm'])
print(movieCd, movieNm, audiAcc)
# Out:
# ['20196309', '20183867', '20184047', '20185353', '20183782', '20185986', '20191601', '20199951', '20196655', '20192151', '20198453', '20190273', '20182585', '20192591', '20192022', '20196657'] ['스파이더맨: 파 프롬 홈', '알라딘', '토이 스토리 4', '기방도령', '기생충', '진범', '극장판 엉덩이 탐정: 화려한 사건 수첩', '애나벨 집으로', '존 윅 3: 파라벨룸', '미드소마', '롱 리브 더 킹: 목포 영웅', '천로역정: 천국을 찾아서', '비스트', 'BIFAN2019 판타스틱 단편 걸작선 1', '마담 싸이코', '맨 인 블랙: 인터내셔널'] [6685160, 10161238, 3151063, 220182, 9919835, 106756, 101245, 459037, 913066, 45707, 1076588, 228365, 199009, 25000, 37437, 843649]

# %%
total = {}
for i in range(3):
    for j in range(10):
        if response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'] not in movieCd:
            audiAcc.append(int(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['audiAcc']))
            movieCd.append(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'])
            movieNm.append(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieNm'])
            total[movieNm[i*j]][movieCd[i*j]] = audiAcc[i*j]
            
print(movieCd, movieNm, audiAcc)
print(total)
# Out:
# ['20196309', '20183867', '20184047', '20185353', '20183782', '20185986', '20191601', '20199951', '20196655', '20192151', '20198453', '20190273', '20182585', '20192591', '20192022', '20196657'] ['스파이더맨: 파 프롬 홈', '알라딘', '토이 스토리 4', '기방도령', '기생충', '진범', '극장판 엉덩이 탐정: 화려한 사건 수첩', '애나벨 집으로', '존 윅 3: 파라벨룸', '미드소마', '롱 리브 더 킹: 목포 영웅', '천로역정: 천국을 찾아서', '비스트', 'BIFAN2019 판타스틱 단편 걸작선 1', '마담 싸이코', '맨 인 블랙: 인터내셔널'] [6685160, 10161238, 3151063, 220182, 9919835, 106756, 101245, 459037, 913066, 45707, 1076588, 228365, 199009, 25000, 37437, 843649]
# {}

# %%
per = {}
total = {}
audiAcc = []
movieCd = []
movieNm = []
for i in range(3):
    for j in range(10):
        if response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'] not in movieCd:
            audiAcc.append(int(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['audiAcc']))
            movieCd.append(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieCd'])
            movieNm.append(response[i]['boxOfficeResult']['weeklyBoxOfficeList'][j]['movieNm'])
            per['코드'] = movieCd[-1]
            per['누적순위'] = audiAcc[-1]
            total[movieNm[-1]] = per

print(total)
# Out:
# {'스파이더맨: 파 프롬 홈': {'코드': '20196657', '누적순위': 843649}, '알라딘': {'코드': '20196657', '누적순위': 843649}, '토이 스토리 4': {'코드': '20196657', '누적순위': 843649}, '기방도령': {'코드': '20196657', '누적순위': 843649}, '기생충': {'코드': '20196657', '누적순위': 843649}, '진범': {'코드': '20196657', '누적순위': 843649}, '극장판 엉덩이 탐정: 화려한 사건 수첩': {'코드': '20196657', '누적순위': 843649}, '애나벨 집으로': {'코드': '20196657', '누적순위': 843649}, '존 윅 3: 파라벨룸': {'코드': '20196657', '누적순위': 843649}, '미드소마': {'코드': '20196657', '누적순위': 843649}, '롱 리브 더 킹: 목포 영웅': {'코드': '20196657', '누적순위': 843649}, '천로역정: 천국을 찾아서': {'코드': '20196657', '누적순위': 843649}, '비스트': {'코드': '20196657', '누적순위': 843649}, 'BIFAN2019 판타스틱 단편 걸작선 1': {'코드': '20196657', '누적순위': 843649}, '마담 싸이코': {'코드': '20196657', '누적순위': 843649}, '맨 인 블랙: 인터내셔널': {'코드': '20196657', '누적순위': 843649}}

# %%
diction = {}
diction['지민'] = 25
print(diction)
# Out:
# {'지민': 25}

# %%
ff = []
ff.append()
